# %%
import pandas as pd
weather = pd.read_csv("気象データ.csv",encoding="ANSI",index_col=0, header=3)
ice = pd.read_csv("アイスクリーム.csv",encoding="ANSI",index_col=0)

# %%
weather
# Out:
#           平均気温(℃)  降水量の合計(mm)  日照時間(時間)  平均気温(℃).1  降水量の合計(mm).1  日照時間(時間).1  \
# 2020年9月      20.1        53.5     140.1       24.2         117.5       105.7
# 2020年10月     13.1        66.0     152.9       17.5         205.0       113.9
# 2020年11月      6.3       113.0      84.0       14.0          14.5       156.6
# 2020年12月     -1.6        26.5      95.2        7.7          13.0       167.9
# 2021年1月      -4.4        90.5     109.5        5.4          43.5       172.4
# 2021年2月      -2.2        78.5     114.2        8.5          88.5       214.9
# 2021年3月       3.8        79.5     161.7       12.8         173.0       193.2
# 2021年4月       7.9       112.0     207.1       15.1         156.0       218.5
# 2021年5月      13.1        76.5     148.5       19.6          99.5       150.5
# 2021年6月      18.9        50.5     260.7       22.7         168.5       131.6
# 2021年7月      23.9         7.5     285.3       25.9         310.0       160.2
# ...

# %%
ice
# Out:
#                  世帯区分       地域区分   時間軸（月次）  /品目分類（2020年改定）  \
# 表章項目
# 金額    二人以上の世帯（2000年～）  01100 札幌市   2020年9月             NaN
# 金額    二人以上の世帯（2000年～）  01100 札幌市  2020年10月             NaN
# 金額    二人以上の世帯（2000年～）  01100 札幌市  2020年11月             NaN
# 金額    二人以上の世帯（2000年～）  01100 札幌市  2020年12月             NaN
# 金額    二人以上の世帯（2000年～）  01100 札幌市   2021年1月             NaN
# ...               ...        ...       ...             ...
# 金額    二人以上の世帯（2000年～）  40130 福岡市   2021年5月             NaN
# 金額    二人以上の世帯（2000年～）  40130 福岡市   2021年6月             NaN
# 金額    二人以上の世帯（2000年～）  40130 福岡市   2021年7月             NaN
# 金額    二人以上の世帯（2000年～）  40130 福岡市   2021年8月             NaN
# 金額    二人以上の世帯（2000年～）  40130 福岡市   2021年9月             NaN
#
#      356 アイスクリーム・シャーベット【円】
# 表章項目
# 金額                     938
# 金額                     482
# 金額                     513
# 金額                     718
# 金額                     614
# ...                    ...
# 金額                   1,074
# ...

# %%
print("札幌")
print("気温の平均値" + str(weather.mean()["平均気温(℃)"]))
print("気温の標準偏差" + str(weather.std()["平均気温(℃)"]))
print("降水量の平均値" + str(weather.mean()["降水量の合計(mm)"]))
print("降水量の標準偏差" + str(weather.std()["降水量の合計(mm)"]))
print("日照時間の平均値" + str(weather.mean()["日照時間(時間)"]))
print("日照時間の標準偏差" + str(weather.std()["日照時間(時間)"]))
# Out:
# 札幌
# 気温の平均値10.815384615384618
# 気温の標準偏差9.900155398935762
# 降水量の平均値71.96153846153847
# 降水量の標準偏差31.81486912492172
# 日照時間の平均値165.21538461538464
# 日照時間の標準偏差61.48040129658999

# %%
print("東京")
print("気温の平均値" + str(weather.mean()["平均気温(℃).1"]))
print("気温の標準偏差" + str(weather.std()["平均気温(℃).1"]))
print("降水量の平均値" + str(weather.mean()["降水量の合計(mm).1"]))
print("降水量の標準偏差" + str(weather.std()["降水量の合計(mm).1"]))
print("日照時間の平均値" + str(weather.mean()["日照時間(時間).1"]))
print("日照時間の標準偏差" + str(weather.std()["日照時間(時間).1"]))
# Out:
# 東京
# 気温の平均値17.161538461538463
# 気温の標準偏差7.245750301790522
# 降水量の平均値153.3846153846154
# 降水量の標準偏差109.75581872315355
# 日照時間の平均値158.59230769230768
# 日照時間の標準偏差38.156333278117394

# %%
print("名古屋")
print("気温の平均値" + str(weather.mean()["平均気温(℃).2"]))
print("気温の標準偏差" + str(weather.std()["平均気温(℃).2"]))
print("降水量の平均値" + str(weather.mean()["降水量の合計(mm).2"]))
print("降水量の標準偏差" + str(weather.std()["降水量の合計(mm).2"]))
print("日照時間の平均値" + str(weather.mean()["日照時間(時間).2"]))
print("日照時間の標準偏差" + str(weather.std()["日照時間(時間).2"]))
# Out:
# 名古屋
# 気温の平均値17.43846153846154
# 気温の標準偏差7.932689588189122
# 降水量の平均値179.30769230769232
# 降水量の標準偏差109.73387096014356
# 日照時間の平均値170.7923076923077
# 日照時間の標準偏差24.611056510521905

# %%
print("大阪")
print("気温の平均値" + str(weather.mean()["平均気温(℃).3"]))
print("気温の標準偏差" + str(weather.std()["平均気温(℃).3"]))
print("降水量の平均値" + str(weather.mean()["降水量の合計(mm).3"]))
print("降水量の標準偏差" + str(weather.std()["降水量の合計(mm).3"]))
print("日照時間の平均値" + str(weather.mean()["日照時間(時間).3"]))
print("日照時間の標準偏差" + str(weather.std()["日照時間(時間).3"]))
# Out:
# 大阪
# 気温の平均値18.092307692307692
# 気温の標準偏差7.688136048317297
# 降水量の平均値164.19230769230768
# 降水量の標準偏差105.78821974065654
# 日照時間の平均値175.65384615384616
# 日照時間の標準偏差24.90912200328143

# %%
print("福岡")
print("気温の平均値" + str(weather.mean()["平均気温(℃).4"]))
print("気温の標準偏差" + str(weather.std()["平均気温(℃).4"]))
print("降水量の平均値" + str(weather.mean()["降水量の合計(mm).4"]))
print("降水量の標準偏差" + str(weather.std()["降水量の合計(mm).4"]))
print("日照時間の平均値" + str(weather.mean()["日照時間(時間).4"]))
print("日照時間の標準偏差" + str(weather.std()["日照時間(時間).4"]))
# Out:
# 福岡
# 気温の平均値18.615384615384617
# 気温の標準偏差7.395251421672125
# 降水量の平均値167.69230769230768
# 降水量の標準偏差230.32174402177225
# 日照時間の平均値170.53076923076924
# 日照時間の標準偏差30.0913161508816

# %%
df_concat = pd.concat([weather, ice])

# %%
df_concat
# Out:
#           平均気温(℃)  降水量の合計(mm)  日照時間(時間)  平均気温(℃).1  降水量の合計(mm).1  日照時間(時間).1  \
# 2020年9月      20.1        53.5     140.1       24.2         117.5       105.7
# 2020年10月     13.1        66.0     152.9       17.5         205.0       113.9
# 2020年11月      6.3       113.0      84.0       14.0          14.5       156.6
# 2020年12月     -1.6        26.5      95.2        7.7          13.0       167.9
# 2021年1月      -4.4        90.5     109.5        5.4          43.5       172.4
# ...           ...         ...       ...        ...           ...         ...
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
#
# ...

# %%
print(df_concat["平均気温(℃)"].corr(df_concat["356 アイスクリーム・シャーベット【円】"]))
# Out:
# nan

# %%
df_concat
# Out:
#           平均気温(℃)  降水量の合計(mm)  日照時間(時間)  平均気温(℃).1  降水量の合計(mm).1  日照時間(時間).1  \
# 2020年9月      20.1        53.5     140.1       24.2         117.5       105.7
# 2020年10月     13.1        66.0     152.9       17.5         205.0       113.9
# 2020年11月      6.3       113.0      84.0       14.0          14.5       156.6
# 2020年12月     -1.6        26.5      95.2        7.7          13.0       167.9
# 2021年1月      -4.4        90.5     109.5        5.4          43.5       172.4
# ...           ...         ...       ...        ...           ...         ...
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
# 金額            NaN         NaN       NaN        NaN           NaN         NaN
#
# ...
